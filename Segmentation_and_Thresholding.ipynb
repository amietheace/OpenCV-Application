# %%
# Segmentation- dividing the image into various regions
# Thresholding- basic segmentation
# [[10 24]
#  [34 67]]
# th = 50
# if th > 50 pixel = 255
# else pixel = 0
# after thresholding [[0 0]
#                   [0 255]]
# ret, out = cv2.threshold(img, th, max_val, algo)

import cv2
import matplotlib.pyplot as plt

def main():
    
    path = "D:\\CV_and_NLP\\opencv\\dataset\\"

    imgpath1 =  path + "gray21.512.tiff"
    
#    imgpath1 =  path + "4.2.07.tiff"

    img = cv2.imread(imgpath1, 1)
    
#    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    th = 127
    max_val = 255
    
    ret, o1 = cv2.threshold(img, th, max_val, cv2.THRESH_BINARY)
    ret, o2 = cv2.threshold(img, th, max_val, cv2.THRESH_BINARY_INV)
    ret, o3 = cv2.threshold(img, th, max_val, cv2.THRESH_TOZERO)
    ret, o4 = cv2.threshold(img, th, max_val, cv2.THRESH_TOZERO_INV)
    ret, o5 = cv2.threshold(img, th, max_val, cv2.THRESH_TRUNC)
    
    output = [img, o1, o2, o3, o4, o5]
    
    titles = ['Original', 'Binary', 'Binary Inv',
              'Zero', 'Zero Inv', 'Trunc']
    
    for i in range(6):
        plt.subplot(2, 3, i+1)
        plt.imshow(output[i])
        plt.title(titles[i])
        plt.xticks([])
        plt.yticks([])

    plt.show()  

if __name__ == "__main__":
    main()

# %%
import cv2
import matplotlib.pyplot as plt

def main():
    
    path = "D:\\CV_and_NLP\\opencv\\dataset\\"

#    imgpath1 =  path + "gray21.512.tiff"
    
    imgpath1 =  path + "4.2.07.tiff"

    img = cv2.imread(imgpath1, 1)
    
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    th = 127
    max_val = 255
    
    ret, o1 = cv2.threshold(img, th, max_val, cv2.THRESH_BINARY)
    ret, o2 = cv2.threshold(img, th, max_val, cv2.THRESH_BINARY_INV)
    ret, o3 = cv2.threshold(img, th, max_val, cv2.THRESH_TOZERO)
    ret, o4 = cv2.threshold(img, th, max_val, cv2.THRESH_TOZERO_INV)
    ret, o5 = cv2.threshold(img, th, max_val, cv2.THRESH_TRUNC)
    
    output = [img, o1, o2, o3, o4, o5]
    
    titles = ['Original', 'Binary', 'Binary Inv',
              'Zero', 'Zero Inv', 'Trunc']
    
    for i in range(6):
        plt.subplot(2, 3, i+1)
        plt.imshow(output[i])
        plt.title(titles[i])
        plt.xticks([])
        plt.yticks([])

    plt.show()  

if __name__ == "__main__":
    main()

# %%
# Otsu's Binarization Thresholding
# this can Automatically calculate threshold value

import cv2
import matplotlib.pyplot as plt

def main():
    
    path = "D:\\CV_and_NLP\\opencv\\dataset\\"

    imgpath1 =  path + "7.1.10.tiff"
    
#    imgpath1 =  path + "4.2.07.tiff"

    img = cv2.imread(imgpath1, 0)
    
#    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    th = 0
    max_val = 255
    
    ret, o1 = cv2.threshold(img, th, max_val, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    ret, o2 = cv2.threshold(img, th, max_val, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    ret, o3 = cv2.threshold(img, th, max_val, cv2.THRESH_TOZERO + cv2.THRESH_OTSU)
    ret, o4 = cv2.threshold(img, th, max_val, cv2.THRESH_TOZERO_INV + cv2.THRESH_OTSU)
    ret, o5 = cv2.threshold(img, th, max_val, cv2.THRESH_TRUNC + cv2.THRESH_OTSU)
    
    output = [img, o1, o2, o3, o4, o5]
    
    titles = ['Original', 'Binary', 'Binary Inv',
              'Zero', 'Zero Inv', 'Trunc']
    
    for i in range(6):
        plt.subplot(2, 3, i+1)
        plt.imshow(output[i], cmap='gray')
        plt.title(titles[i])
        plt.xticks([])
        plt.yticks([])

    plt.show()  

if __name__ == "__main__":
    main()

# %%
import cv2
import matplotlib.pyplot as plt

def main():
    
    path = "D:\\CV_and_NLP\\opencv\\dataset\\"

    imgpath1 =  path + "7.1.08.tiff"
    
#    imgpath1 =  path + "4.2.07.tiff"

    img = cv2.imread(imgpath1, 0)
    
#    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    th = 0
    max_val = 255
    
    ret, o1 = cv2.threshold(img, th, max_val, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    ret, o2 = cv2.threshold(img, th, max_val, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    ret, o3 = cv2.threshold(img, th, max_val, cv2.THRESH_TOZERO + cv2.THRESH_OTSU)
    ret, o4 = cv2.threshold(img, th, max_val, cv2.THRESH_TOZERO_INV + cv2.THRESH_OTSU)
    ret, o5 = cv2.threshold(img, th, max_val, cv2.THRESH_TRUNC + cv2.THRESH_OTSU)
    
    output = [img, o1, o2, o3, o4, o5]
    
    titles = ['Original', 'Binary', 'Binary Inv',
              'Zero', 'Zero Inv', 'Trunc']
    
    for i in range(6):
        plt.subplot(2, 3, i+1)
        plt.imshow(output[i], cmap='gray')
        plt.title(titles[i])
        plt.xticks([])
        plt.yticks([])

    plt.show()  

if __name__ == "__main__":
    main()

# %%
# Adaptive thresholding
# We use this in case of images of changing lightning conditions
import cv2
import matplotlib.pyplot as plt

def main():
    
    path = "D:\\CV_and_NLP\\opencv\\dataset\\"

    imgpath1 =  path + "5.1.09.tiff"
    
#    imgpath1 =  path + "4.2.07.tiff"

    img = cv2.imread(imgpath1, 0)
    
#    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    block_size = 11
    constant = 2
    
    th1 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, block_size, constant)
    th2 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, block_size, constant)
    
    
    output = [img, th1, th2]
    
    titles = ['Original', 'Mean Adaptive', 'Gaussian Adaptive']
    
    for i in range(3):
        plt.subplot(1, 3, i+1)
        plt.imshow(output[i], cmap='gray')
        plt.title(titles[i])
        plt.xticks([])
        plt.yticks([])

    plt.show()  

if __name__ == "__main__":
    main()

# %%
import cv2
import matplotlib.pyplot as plt

def main():
    
    path = "D:\\CV_and_NLP\\opencv\\dataset\\"

    imgpath1 =  path + "5.1.12.tiff"
    
#    imgpath1 =  path + "4.2.07.tiff"

    img = cv2.imread(imgpath1, 0)
    
#    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    block_size = 11
    constant = 2
    
    th1 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, block_size, constant)
    th2 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, block_size, constant)
    
    
    output = [img, th1, th2]
    
    titles = ['Original', 'Mean Adaptive', 'Gaussian Adaptive']
    
    for i in range(3):
        plt.subplot(1, 3, i+1)
        plt.imshow(output[i], cmap='gray')
        plt.title(titles[i])
        plt.xticks([])
        plt.yticks([])

    plt.show()  

if __name__ == "__main__":
    main()

# %%
# Keep changing blocksize for more clearity
import cv2
import matplotlib.pyplot as plt

def main():
    
    path = "D:\\CV_and_NLP\\opencv\\dataset\\"

    imgpath1 =  path + "5.1.12.tiff"
    
#    imgpath1 =  path + "4.2.07.tiff"

    img = cv2.imread(imgpath1, 0)
    
#    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    block_size = 513
    constant = 2
    
    th1 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, block_size, constant)
    th2 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, block_size, constant)
    
    
    output = [img, th1, th2]
    
    titles = ['Original', 'Mean Adaptive', 'Gaussian Adaptive']
    
    for i in range(3):
        plt.subplot(1, 3, i+1)
        plt.imshow(output[i], cmap='gray')
        plt.title(titles[i])
        plt.xticks([])
        plt.yticks([])

    plt.show()  

if __name__ == "__main__":
    main()

# %%
# Using Adaptive thresholding in color image
# convert that into grayscale
import cv2
import matplotlib.pyplot as plt

def main():
    
    path = "D:\\CV_and_NLP\\opencv\\dataset\\"

    imgpath1 =  path + "4.1.05.tiff"
    
#    imgpath1 =  path + "4.2.07.tiff"

    img = cv2.imread(imgpath1, 0)
    
#    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    block_size = 513
    constant = 2
    
    th1 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, block_size, constant)
    th2 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, block_size, constant)
    
    
    output = [img, th1, th2]
    
    titles = ['Original', 'Mean Adaptive', 'Gaussian Adaptive']
    
    for i in range(3):
        plt.subplot(1, 3, i+1)
        plt.imshow(output[i], cmap='gray')
        plt.title(titles[i])
        plt.xticks([])
        plt.yticks([])

    plt.show()  

if __name__ == "__main__":
    main()

# %%
# Thresholding Live webcam feed

import cv2

def main():
    
    windowName = ['Binary', 'Binary Inv', 'Zero', 'Zero Inv', 'Trunc']
    
    cap = cv2.VideoCapture(0)
    
    if cap.isOpened():
        ret, frame = cap.read()
    else:
        ret = False


    while ret:
    
        ret, frame = cap.read()
        
        th = 127
        max_val = 255
    
        ret, o1 = cv2.threshold(frame, th, max_val, cv2.THRESH_BINARY)
        ret, o2 = cv2.threshold(frame, th, max_val, cv2.THRESH_BINARY_INV)
        ret, o3 = cv2.threshold(frame, th, max_val, cv2.THRESH_TOZERO)
        ret, o4 = cv2.threshold(frame, th, max_val, cv2.THRESH_TOZERO_INV)
        ret, o5 = cv2.threshold(frame, th, max_val, cv2.THRESH_TRUNC)
        
        cv2.imshow(windowName[0], o1)
        cv2.imshow(windowName[1], o2)
        cv2.imshow(windowName[2], o3)
        cv2.imshow(windowName[3], o4)
        cv2.imshow(windowName[4], o5)
        if cv2.waitKey(1) == 27:
            break

    cv2.destroyAllWindows()
    cap.release()

if __name__ == "__main__":
    main()
